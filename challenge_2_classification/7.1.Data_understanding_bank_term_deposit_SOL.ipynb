# %% [markdown]
# # Data Understanding
#
# Perform the necessary steps to better understand the data.
#
# We omit the step of data collection because I give you all the necessary data.

# %% [markdown]
# ### Imports

# %%
# Import necessary libraries, functions, objects...

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load dataset

# %%
df = pd.read_csv('../data/bank_term_deposit/bank_term_deposit.csv')

# %% [markdown]
# ## Describe the data
#
# Perform a first, basic, inspection of the data: dimensions, first rows, column types, etc.

# %%
df.shape
# Out:
# (3063, 19)

# %%
df.head()
# Out:
#    id    split  age          job   marital  education default  balance  \
# 0   1  labeled   31   management   married   tertiary      no      460
# 1   2  labeled   34  blue-collar   married  secondary      no     1826
# 2   3  labeled   50  blue-collar   married  secondary      no      290
# 3   4  labeled   42       admin.  divorced  secondary      no     1077
# 4   5  labeled   47     services    single  secondary      no       41
#
#   housing loan   contact  day month  duration  campaign  pdays  previous  \
# 0      no   no  cellular   28   aug        13        14     -1         0
# 1     yes   no   unknown   20   may       203         2     -1         0
# 2     yes   no  cellular    7   aug       226         3     -1         0
# 3     yes   no   unknown   14   may       213         1     -1         0
# 4     yes   no  cellular    5   may       298         1     -1         0
#
#   poutcome   y
# 0  unknown  no
# 1  unknown  no
# 2  unknown  no
# 3  unknown  no
# 4  unknown  no

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3063 entries, 0 to 3062
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3063 non-null   int64
#  1   split      3063 non-null   str
#  2   age        3063 non-null   int64
#  3   job        3063 non-null   str
#  4   marital    3063 non-null   str
#  5   education  3063 non-null   str
#  6   default    3063 non-null   str
#  7   balance    3063 non-null   int64
#  8   housing    3063 non-null   str
#  9   loan       3063 non-null   str
#  10  contact    3063 non-null   str
#  11  day        3063 non-null   int64
#  12  month      3063 non-null   str
#  13  duration   3063 non-null   int64
#  14  campaign   3063 non-null   int64
#  15  pdays      3063 non-null   int64
#  16  previous   3063 non-null   int64
#  17  poutcome   3063 non-null   str
#  18  y          2007 non-null   str
# dtypes: int64(8), str(11)
# memory usage: 454.8 KB

# %%
df.describe().T
# Out:
#            count         mean          std     min    25%     50%     75%  \
# id        3063.0  1843.997388  1029.326516     1.0  950.5  1886.0  2755.5
# age       3063.0    40.916422     9.921551    19.0   33.0    39.0    48.0
# balance   3063.0  1313.493960  2768.188907 -2076.0   58.0   394.0  1334.5
# day       3063.0    16.133203     8.245610     1.0    9.0    16.0    22.0
# duration  3063.0   205.055828   204.119886     4.0   89.0   153.0   247.0
# campaign  3063.0     2.903363     3.183655     1.0    1.0     2.0     3.0
# pdays     3063.0    34.445642    96.050959    -1.0   -1.0    -1.0    -1.0
# previous  3063.0     0.434215     1.475524     0.0    0.0     0.0     0.0
#
#               max
# id         3521.0
# age          87.0
# balance   42042.0
# day          31.0
# duration   2456.0
# campaign     44.0
# pdays       871.0
# previous     23.0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Summarize main characteristics of the data with visualizations.

# %% [markdown]
# ### Feature distributions
#
# Check the distributions of numerical features (histogram or boxplot) and categorical features (bar plot).

# %% [markdown]
# #### Numerical features

# %%
df.drop(columns='id').hist(figsize=(10, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Categorical features

# %%
import math

cats = df.drop(columns='split').select_dtypes(include=['object', 'category'])
n = len(cats.columns)
cols_per_row = 4

rows = math.ceil(n / cols_per_row)
fig, axes = plt.subplots(rows, cols_per_row, figsize=(5*cols_per_row, 4*rows))
axes = axes.flatten()

for i, col in enumerate(cats.columns):
    df[col].value_counts().plot(kind='bar', ax=axes[i], title=col)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Count')

# Hide any unused subplots
for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
to_check = ['default', 'poutcome', 'month']

for col in to_check:
    print(df[col].value_counts(dropna=False))
    print()
# Out:
# default
# no     3008
# yes      55
# Name: count, dtype: int64
#
# poutcome
# unknown    2604
# failure     286
# other        97
# success      76
# Name: count, dtype: int64
#
# month
# may    1029
# jul     485
# aug     449
# jun     386
# nov     246
# apr     164
# feb     118
# jan      93
# oct      35
# sep      29
# dec      15
# mar      14
# Name: count, dtype: int64

# %% [markdown]
# ### Feature correlation
#
# Display the correlation between pairs of features. This is normally done with the correlation matrix.
#
# Also, display in the same plot or a different one the correlation of features with the target feature.

# %%
plt.figure(figsize=(10, 10))
corrs = df.drop(columns=['id', 'split']).corr(numeric_only=True)
sns.heatmap(corrs, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ### Pairplot
#
# Visualize the relationship of different features with a pairplot.

# %%
fts2pair = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous', 'y']

# %%
sns.pairplot(df[fts2pair])
plt.show()

# %% [markdown]
# ## Verify Data Quality
#
# - Is the data correct? Does any column contain important errors that should be corrected?
# - What about missing values?
#     - How are they represented (e.g., empty string, NaN, -1, etc.)?
#     - Where do they occur?
#     - How common are they?
# - Do not change the data, just inspect where these problems occur.

# %% [markdown]
# ### Nulls

# %%
# Null proportion
for col in df.columns:
    is_col_unknown = False
    if df[col].dtype == 'object':
        is_col_unknown = 'unknown' in df[col].str.lower().values
    is_col_minus1 = -1 in df[col].values and col != 'balance'
    if is_col_unknown or is_col_minus1:
        print(col)
        n_nan = df[col].isin(['unknown', '?', -1]).sum()
        print(f'{n_nan / len(df):.1%} unknown values')
        print()
# Out:
# job
# 0.9% unknown values
#
# education
# 3.9% unknown values
#
# contact
# 33.3% unknown values
#
# pdays
# 85.0% unknown values
#
# poutcome
# 85.0% unknown values

# %% [markdown]
# Check all `pdays` nulls correspond to `poutcome` nulls and vice versa.

# %%
assert list(df['pdays'] == -1) == list(df['poutcome'] == 'unknown')

# %% [markdown]
# All `y` nulls are leaderboard as expected. These are OK.

# %%
assert list(df['y'].isna()) == list(df['split'] == 'leaderboard')

# %% [markdown]
# ### Duplicates
#
# No duplicates.

# %%
df['id'].duplicated().any()
# Out:
# np.False_

# %%
# Are there duplicates after removing these columns?
df.drop(columns=['split', 'id', 'y']).duplicated().any()
# Out:
# np.False_
