# %% [markdown]
# # Pandas 2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Edat mitjana per gènere i classe
#
# Troba l'edat mitjana dels passatgers basant-te tant en el seu gènere (Sex) com en la seva classe (Pclass).

# %% [markdown]
# ## Taxes de supervivència per trams d'edat
#
# Agrupa els passatgers en trams d'edat (p. ex. 0-9, 10-19, 20-29, ...), i calcula la taxa de supervivència per a cada tram.

# %% [markdown]
# ## Mètriques de tarifes
#
# Calcula i mostra la mitjana, la mediana i la desviació estàndard de les tarifes dels passatgers que van sobreviure i dels que no.

# %% [markdown]
# ## Supervivència per coberta
#
# La primera lletra del número de cabina representa la coberta. Determina la taxa de supervivència per a cada coberta.

# %% [markdown]
# ## Qui va sol i qui no
#
# La columna `sibsp` indica germans i cònjuges. La columna `parch` indica pares i fills.
#
# Defineix "sol" com algú que no té germans/cònjuges/pares/fills a bord. Calcula la taxa de supervivència dels passatgers que anaven "sols" comparat amb els que no.

# %% [markdown]
# ## Mida de la família
#
# Calcula la taxa de supervivència basant-te en la mida de la família. La mida de la família és la suma de germans/cònjuges (columna `sibsp`) i pares/fills (columna `parch`).

# %% [markdown]
# ## Poder adquisitiu
#
# Calcula i classifica el poder adquisitiu dels passatgers com a 'Low', 'Medium' i 'High' basant-te en la tarifa que van pagar. Defineix les categories utilitzant el percentil 33 i el 66 de les tarifes com a llindars.

# %% [markdown]
# ## Taxa de supervivència per port d'embarcament
#
# Dibuixa les taxes de supervivència dels passatgers basant-te en el port des d'on van embarcar.

# %% [markdown]
# ## Distribució de tarifes
#
# Dibuixa la distribució de tarifes pagades pels passatgers, segmentada pel seu estat de supervivència (van sobreviure o no).

# %% [markdown]
# ## Gràfic de dispersió Edat vs. Tarifa
#
# Crea un gràfic de dispersió per mostrar la relació entre edat i tarifa, amb colors diferents segons l'estat de supervivència.

# %% [markdown]
# ## Boxplot de tarifes per classe
#
# Mostra un boxplot per comparar la distribució de tarifes entre les diferents classes.
