# %% [markdown]
# # Exercicis de Numpy
#
# - Tots els exercicis d'aquesta secció s'han d'implementar utilitzant la biblioteca `numpy`.
# - La gran majoria dels exercicis es poden resoldre **sense** cap bucle `for` o `while`, només utilitzant les funcions de Numpy o operacions vectoritzades.
# - La gran majoria dels exercicis es poden resoldre amb un màxim d'1-6 línies de codi.
# - Si no saps com resoldre alguna cosa, no dubtis a buscar a Internet sobre el teu problema. Per exemple, `"Com ordenar un array en Numpy?"`.
# - És millor que no facis servir ChatGPT per trobar la solució, així t'acostumes a programar amb `numpy`.

# %%
import numpy as np

# %% [markdown]
# ## Estadístiques
#
# Crea un vector aleatori de longitud 10 i troba el mínim, el màxim, la mitjana i la desviació estàndard.

# %%
vector_nums = np.random.randint(10, dtype=int)

print(vector_nums)
# Out:
# 0

# %% [markdown]
# ## Dates
#
# Obté les dates d'avui, ahir i demà. Per a la data d'avui, pots utilitzar `np.datetime64('today')` i després restar o sumar 1 dia a aquesta data.

# %% [markdown]
# ## Setembre
#
# Obté totes les dates del setembre de 2023.

# %% [markdown]
# ## Setmana
#
# Crea un array de dates que comenci avui i abasti els 7 dies següents.

# %% [markdown]
# ## Diferència
#
# Donat un array de dates, troba les diferències (en dies) entre cada data i la primera data.

# %%
dates = np.array(['2023-08-14', '2023-08-17', '2023-08-20', '2025-10-10'], dtype='datetime64')

# %% [markdown]
# ## NaN
#
# Quin serà el resultat de les sentències següents?
#
# Primer prova d'entendre els conceptes de `np.nan`, `np.inf` i `set`. A continuació, prova de resoldre mentalment les sentències utilitzant la teva lògica. Finalment, comprova si els resultats esperats són correctes.
#
# ```python
# 0 * np.nan
# np.nan == np.nan
# np.inf > np.nan
# np.nan - np.nan
# np.nan in set([np.nan])
# ```

# %% [markdown]
# ## Mitjana més alta
#
# Donada una matriu 10x10 de valors aleatoris entre 0 i 1, troba i imprimeix la fila amb el valor mitjà més alt.

# %% [markdown]
# ## Python vs Numpy
#
# Per a cadascun dels exercicis següents, implementa les funcions utilitzant només Python, sense cap biblioteca externa. A continuació, compara el temps d'execució amb la comanda màgica `%%timeit` (vegeu el primer exemple).

# %% [markdown]
# ### Màxim
#
# Escriu una funció en Python que trobi el valor màxim d'una llista de nombres. Codifica-la tu mateix, no utilitzis la funció `max()` de Python.
#
# Crea una llista de nombres aleatoris amb 10.000 elements o més.
#
# A continuació, comprova el temps mitjà que triga a executar-se cadascuna de les funcions `max` amb la llista (utilitzant la comanda màgica `%%timeit`):
# - La teva funció `max` personalitzada.
# - La funció integrada `max()` de Python.
# - La funció `max()` de Numpy.

# %% [markdown]
# ### Mitjana
#
# Escriu una funció en Python que trobi el valor mitjà d'una llista de nombres. Codifica-la tu mateix, no utilitzis la funció `mean()` de Numpy.
#
# Crea una llista de nombres aleatoris amb 10.000 elements o més.
#
# A continuació, comprova el temps mitjà que triga a executar-se cadascuna de les funcions `mean` amb la llista (utilitzant la comanda màgica `%%timeit`):
# - La teva funció `mean` personalitzada.
# - La funció `mean()` de Numpy.

# %% [markdown]
# ## Viatger del temps
#
# Un historiador viatger del temps vol estudiar els grans esdeveniments del segle passat. Crea un array de dates des del 1923-08-14 fins al 2023-08-14 en increments de 10 anys, i després selecciona aleatòriament 3 dates a les quals viatjar.

# %% [markdown]
# ## Registre de temperatura
#
# Implementa la funció `detect_temperature_anomalies(values)`.
#
# Tens un registre de temperatures de 365 dies d'una ciutat, representat com un array de floats. Identifica els dies en què la temperatura està com a mínim a 2 desviacions estàndard de la mitjana.

# %%
# Temperatures simulades al voltant de 25°C amb desviació estàndard de 5°C
temps = np.random.normal(25, 5, 365)
detect_temperature_anomalies(temps)
