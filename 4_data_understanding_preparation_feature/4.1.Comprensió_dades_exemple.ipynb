# %% [markdown]
# ## Llibraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Carrega les dades

# %%
df = pd.read_csv('../data/occupation.csv', sep='|')

# %% [markdown]
# ## Primera inspecció

# %%
# Dimensions del dataset
df.shape

# %%
# Mostra les primeres files
df.head()

# %%
# Tipus de dades dels atributs
df.dtypes

# %%
# Estadístiques generals per a les columnes numèriques
df.describe().T

# %%
# Informació general, amb dtype i recompte de no-nuls
df.info()

# %%
# Comprova si hi ha valors absents a cada columna
df.isna().any()

# %%
# Comprova les files amb edat absent
df[df['age'].isna()]

# %% [markdown]
# ## Exploració automàtica
#
# Si no està instal·lat: `pip install fg-data-profiling[notebook]`

# %%
from data_profiling import ProfileReport

# %% [markdown]
# Crea el profiling amb algunes opcions:

# %%
profile = ProfileReport(
    df,
    title="Occupation Report",
    explorative=True,  # Manté actives les anàlisis útils de text/tipus
    interactions={
        "continuous": False  # Desactiva la graella massiva de scatter plots per parells
    },
    correlations={
        "pearson": {
            "calculate": True,
            "threshold": 0.85
        },
        # Desactiva completament les alertes de mètriques de fons automàtiques
        "auto": {"calculate": False, "warn_high_correlations": False},
    },
)

# %% [markdown]
# Crea l'informe HTML:

# %%
profile.to_file("reports/occupation_report.html")

# %% [markdown]
# ## EDA manual
#
# EDA d'exemple, si us plau, fes-ho millor.

# %%
numerical_cols = df.drop(columns=['user_id']).select_dtypes(include=np.number).columns.tolist()

# %%
df[numerical_cols].hist();

# %%
# Boxplots per a les columnes numèriques
# Tingues en compte que les unitats són completament diferents, no té sentit dibuixar-les juntes
df[['age']].boxplot();

# %%
df['gender'].value_counts().plot(kind='bar', ylabel='Count');
